# %%
import pandas as pd
Df = pd.read_csv("C://Users//win10//Downloads//INDIAVIX.csv")

# %%
Df.describe()
# Out:
#               Open         High          Low        Close     Previous  \
# count  2769.000000  2769.000000  2769.000000  2769.000000  2768.000000
# mean     19.637037    20.550775    18.297726    19.765841    19.759440
# std       7.917076     8.439532     7.696670     8.063060     8.056558
# min      10.447500    10.807500     8.755000    10.447500    10.447500
# 25%      14.760000    15.255000    13.462500    14.760000    14.760000
# 50%      17.247500    17.990000    16.057500    17.275000    17.273750
# 75%      21.740000    22.860000    20.590000    22.040000    22.021250
# max      83.607500    86.635000    75.972500    83.607500    83.607500
#
#             Change      %Change
# count  2769.000000  2769.000000
# mean     -0.000968     0.001347
# std       1.269633     0.052728
# min     -12.470000    -0.339200
# 25%      -0.480000    -0.026900
# 50%      -0.040000    -0.002200
# 75%       0.460000     0.025500
# max      11.620000     0.643600

# %%
Df.head()
# Out:
#          Date   Open   High    Low  Close  Previous  Change  %Change
# 0  2009-03-02  43.19  43.38  41.44  43.17       NaN    0.00   0.0000
# 1  2009-03-03  43.17  43.90  41.20  43.89     43.17    0.72   0.0167
# 2  2009-03-04  43.89  43.89  42.16  42.52     43.89   -1.37  -0.0312
# 3  2009-03-05  42.52  42.71  40.41  41.49     42.52   -1.03  -0.0242
# 4  2009-03-06  41.49  41.49  37.57  38.16     41.49   -3.33  -0.0803

# %%
Df["High"].max()
# Out:
# 86.635

# %%
Df["High"].between(30,40)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2764    False
# 2765    False
# 2766    False
# 2767    False
# 2768     True
# Name: High, Length: 2769, dtype: bool

# %%
Df[Df["High"].between(30,40)]  #filters the whole table for true false
# Out:
#             Date     Open     High      Low    Close  Previous  Change  \
# 7     2009-03-13  39.2700  39.2700  35.0800  35.5600   39.2700   -3.71
# 8     2009-03-16  35.5600  37.8800  35.5600  36.7000   35.5600    1.14
# 9     2009-03-17  36.7000  38.7600  34.8500  38.4300   36.7000    1.73
# 10    2009-03-18  38.4300  38.8600  36.9900  38.1500   38.4300   -0.28
# 11    2009-03-19  38.1500  38.6000  36.6500  37.7400   38.1500   -0.41
# ...          ...      ...      ...      ...      ...       ...     ...
# 2731  2020-03-11  30.8000  33.2375  29.6500  31.5550   30.8000    0.76
# 2759  2020-04-24  39.2300  39.9475  34.9825  39.1175   39.2300   -0.11
# 2762  2020-04-29  35.3550  35.3550  31.4825  33.8375   35.3550   -1.52
# 2763  2020-04-30  33.8375  34.2525  32.5350  33.9875   33.8375    0.15
# 2768  2020-05-08  39.9300  39.9300  36.5475  38.4075   39.9300   -1.52
#
#       %Change
# 7     -0.0945
# 8      0.0321
# 9      0.0471
# 10    -0.0073
# 11    -0.0107
# ...       ...
# ...

# %%
import matplotlib.pyplot as plt

# %%
y = list(Df.High)
plt.boxplot(y)
plt.show()

# %%
Df.groupby(['Open']).mean()
# Out:
#              High      Low     Close  Previous  Change  %Change
# Open
# 10.4475  11.18750   9.8875  10.86250   10.4475    0.42  0.03970
# 10.5250  11.45250   9.6175  11.00750   10.5250    0.48  0.04580
# 10.5600  10.80750   9.2450  10.63500   10.5600    0.08  0.00710
# 10.6275  11.00625   9.3275  10.66625   10.6275    0.04  0.00365
# 10.6350  12.74500   9.8175  11.78500   10.6350    1.15  0.10810
# ...           ...      ...       ...       ...     ...      ...
# 71.8900  71.89000  63.6075  64.40750   71.8900   -7.48 -0.10410
# 71.9850  86.63500  71.9850  83.60750   71.9850   11.62  0.16150
# 72.1975  72.96500  65.3800  67.10000   72.1975   -5.10 -0.07060
# 77.6250  79.40500  70.6750  71.53250   77.6250   -6.09 -0.07850
# 83.6075  84.59750  75.9725  77.62500   83.6075   -5.98 -0.07160
#
# [2097 rows x 6 columns]

# %%
# Graphs

# %%
# import pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt
  
# create 2D array of table given above
data = [['E001', 'M', 34, 123, 'Normal', 350],
        ['E002', 'F', 40, 114, 'Overweight', 450],
        ['E003', 'F', 37, 135, 'Obesity', 169],
        ['E004', 'M', 30, 139, 'Underweight', 189],
        ['E005', 'F', 44, 117, 'Underweight', 183],
        ['E006', 'M', 36, 121, 'Normal', 80],
        ['E007', 'M', 32, 133, 'Obesity', 166],
        ['E008', 'F', 26, 140, 'Normal', 120],
        ['E009', 'M', 32, 133, 'Normal', 75],
        ['E010', 'M', 36, 133, 'Underweight', 40] ]
  
# dataframe created with
# the above data array
df = pd.DataFrame(data, columns = ['EMPID', 'Gender', 
                                    'Age', 'Sales',
                                    'BMI', 'Income'] )

# %%
df
# Out:
#   EMPID Gender  Age  Sales          BMI  Income
# 0  E001      M   34    123       Normal     350
# 1  E002      F   40    114   Overweight     450
# 2  E003      F   37    135      Obesity     169
# 3  E004      M   30    139  Underweight     189
# 4  E005      F   44    117  Underweight     183
# 5  E006      M   36    121       Normal      80
# 6  E007      M   32    133      Obesity     166
# 7  E008      F   26    140       Normal     120
# 8  E009      M   32    133       Normal      75
# 9  E010      M   36    133  Underweight      40

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Sales'}>],
#        [<AxesSubplot:title={'center':'Income'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
# group by of each string column as a graph

# %%
df.plot.bar()
  
# plot between 2 attributes
plt.bar(df['Age'], df['Sales'])
plt.xlabel("Age")
plt.ylabel("Sales")
plt.show()

# %%
df.plot.bar()
  
# plot between 2 attributes
plt.bar(df['Age'],df['Income'])
plt.xlabel("Age")
plt.show()

# %%
# For each numeric attribute of dataframe
df.plot.box()

# individual attribute box plot
plt.boxplot(df['Income'])
plt.show()

# %%
plt.pie(df['Age'], labels = {"A", "B", "C",
                             "D", "E", "F",
                             "G", "H", "I", "J"},
                               
autopct ='% 1.1f %%', shadow = True)
plt.show()
  
plt.pie(df['Income'], labels = {"A", "B", "C",
                                "D", "E", "F",
                                "G", "H", "I", "J"},
                                  
autopct ='% 1.1f %%', shadow = True)
plt.show()
  
plt.pie(df['Sales'], labels = {"A", "B", "C",
                               "D", "E", "F",
                               "G", "H", "I", "J"},
autopct ='% 1.1f %%', shadow = True)
plt.show()

# %%
# scatter plot between income and age
plt.scatter(df['Income'], df['Age'])
plt.xlabel("Income")
plt.ylabel("Age")
plt.show()
  
# scatter plot between income and sales
plt.scatter(df['Income'], df['Sales'])
plt.show()
  
# scatter plot between sales and age
plt.scatter(df['Sales'], df['Age'])
plt.show()

# %%
# distribution of each column 
# numeric as bar chart for distribution for each column in one graph
# text ones > group by , and vol count as a graph
# automation to do so for all columns , like loop
# decide your target variable , the outcome of that table , sla met percentage
# distribution of pairs as graphs

# %%
# computes various summary statistics, excluding NaN values
df.describe()
# Out:
#              Age       Sales      Income
# count  10.000000   10.000000   10.000000
# mean   34.700000  128.800000  182.200000
# std     5.121849    9.271222  127.533699
# min    26.000000  114.000000   40.000000
# 25%    32.000000  121.500000   90.000000
# 50%    35.000000  133.000000  167.500000
# 75%    36.750000  134.500000  187.500000
# max    44.000000  140.000000  450.000000

# %%
# for computing correlations
df.corr()
# Out:
#              Age     Sales    Income
# Age     1.000000 -0.801643  0.306793
# Sales  -0.801643  1.000000 -0.561347
# Income  0.306793 -0.561347  1.000000

# %%
# computes numerical data ranks
df.rank()
# Out:
#    EMPID  Gender   Age  Sales  BMI  Income
# 0    1.0     7.5   5.0    4.0  2.5     9.0
# 1    2.0     2.5   9.0    1.0  7.0    10.0
# 2    3.0     2.5   8.0    8.0  5.5     6.0
# 3    4.0     7.5   2.0    9.0  9.0     8.0
# 4    5.0     2.5  10.0    2.0  9.0     7.0
# 5    6.0     7.5   6.5    3.0  2.5     3.0
# 6    7.0     7.5   3.5    6.0  5.5     5.0
# 7    8.0     2.5   1.0   10.0  2.5     4.0
# 8    9.0     7.5   3.5    6.0  2.5     2.0
# 9   10.0     7.5   6.5    6.0  9.0     1.0

# %% [markdown]
# https://documentation.help/Python-3.6.3/datatypes.html

# %%
# str
# object  - could store any type of values/ objects in python
# integer
# float
# datetime

# list - mutable, index, duplicates possible, nested possible, miltiple datatypes inside
# dict - pairs ,index,  mutable, duplicates possible, nested possible
# set -  no index,  mutable, no duplicates possible, nested possible
# tuple -   index,  immutable,   duplicates possible, nested possible
# arrays - 
# collections - 
# give one example for each data type and functionality

# %%
# # list
# a=[1,2,3]
# b=[1,2,[3,4,[5,6]]]
# print(b[0])
# # print(b[0][0]) invalid as no value at that position, this position does not exist
# print(b[2][0,1,2])
# print(b[2][2][0(5),1(6)])
# print(b[-1][-1][-1])
# b[2][0,1,2]
# Out:
# 1
# 4
# 6

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# we cant execute python file from command prompt from within python prompt
#
# we could run a .py file if it is in same folder as the cmd prompt that we are in
#
# we could also navigate to that folder
#
# we could specify the full path of the file for execution

# %% [markdown]
# int value limits, byte limits - find , fill here?
#
# str (calculate based on one character)
#
# value limits, byte limits - find , fill here?
#
# long int , float, datetime - same question as above??
# [0,1]
#
# [00,01,10,11] > 0,1,2,3
#
# [000,001,010,011,100,101,110,111] > 0,1,2,3,4,5,6,7

# %% [markdown]
# variable declaration
#
# a=10
#
# 1a=10
#
# a1=10
